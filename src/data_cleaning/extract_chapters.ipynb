# %%
import pandas as pd
import re
from pathlib import Path
from dotenv import load_dotenv
import os

# %%
load_dotenv()

TSV = Path("/home/elisa/OneDrive/Studium/Cultural_Analytics/project/src/crawler/video_data_inc_descriptions_combined.tsv").resolve()
TARGET_DIR = Path(os.getenv("CHAPTERS_DIR")).resolve()
assert TSV.is_file(), "Could not find TSV."
assert TARGET_DIR.is_dir(), "Could not find chapters directory."

# %%
def extract_sections(text: str) -> dict[str, str]:
    """Extracts numbered text sections and optionally Vorfilm section"""

    chapters = []
    contents = []

    # Normalize whitespace
    text = re.sub(r"\s+", " ", text).strip()

    # Optional Vorfilm
    vorfilm_match = re.match(r"(Vorfilm:)(.*?)(?=\s\d{1,2}\.\s)", text)
    if vorfilm_match:
        chapters.append("Vorfilm")
        contents.append(vorfilm_match.group(2).strip())
        text = text[vorfilm_match.end():].strip()

    # Candidate chapter markers (still permissive)
    pattern = re.compile(r"\b(\d{1,2})\.\s")
    matches = list(pattern.finditer(text))

    # Filter by strict ascending sequence
    valid_matches = []
    expected = 1

    for m in matches:
        num = int(m.group(1))
        if num == expected:
            valid_matches.append(m)
            expected += 1

    # Split text using validated matches
    for i, match in enumerate(valid_matches):
        start = match.start()
        end = (
            valid_matches[i + 1].start()
            if i + 1 < len(valid_matches)
            else len(text)
        )

        chapter_num = match.group(1)
        chapter_text = text[start:end].strip()

        chapters.append(chapter_num)
        contents.append(chapter_text)

    return {
        "chapter": chapters,
        "content": contents
    }



def save_chapters(row: pd.Series) -> None:
    print(row)

    assert isinstance(
        row["content"], str
    ), "Function must be applied to rows which have non-null content"
    filename = str(row["episode"]) + "_" + str(row["year"]) + "_chapters.tsv"
    target_filepath = Path(TARGET_DIR / filename).resolve()
    if target_filepath.is_file():
        print("Skip")
        return

    result = extract_sections(row["content"])
    result_df = pd.DataFrame(result)
    print(result_df)
    result_df.to_csv(target_filepath, index=False, sep="\t")

# %%
df = pd.read_csv(TSV, sep="\t")
df.columns
# Out:
# Index(['episode', 'year', 'filestem', 'length', 'fps', 'frames',
#        'url_bundesarchiv', 'url_m3u8', 'keywords', 'content'],
#       dtype='str')

# %%
df[df["content"].isna()].count()
# Out:
# episode             1
# year                1
# filestem            1
# length              1
# fps                 1
# frames              1
# url_bundesarchiv    1
# url_m3u8            1
# keywords            0
# content             0
# dtype: int64

# %%
df[(df["content"].notna()) & df["content"].str.startswith("1.")].count()
# Out:
# episode             180
# year                180
# filestem            180
# length              177
# fps                 177
# frames              177
# url_bundesarchiv    180
# url_m3u8            177
# keywords            180
# content             180
# dtype: int64

# %%
df["content"].iloc[4]
# Out:
# 'Vorfilm: Verwundetenversorgung der deutschen Wehrmacht Straßenkampf in einer französischen Stadt: Verwundete werden in Sicherheit gebracht und mit einem Transportflugzeug (Junkers Ju 52) aus dem Kampfgebiet geflogen. Schwestern und Sanitäter des Deutschen Roten Kreuzes (DRK) im Einsatz, bei der Pflege und der Betreuung der Verwundeten und dem Transport mit Zügen und Sankas. Betreuung in einem Lazarett in Deutschland, Plakat des Kriegshilfswerks des DRK zum Spendenaufruf. Vorfilm: Tran und Helle, Benzinverbrauch Tran und Helle unterhalten sich in einer Gaststätte mit einem Mann und einer Frau. Es geht um den Benzinverbrauch beim Autofahren. Es wird darauf hingewiesen, dass man keinerlei unnötige Fahrten machen solle, da das Benzin für den Krieg benötigt wird. (00:03:35) 1. Staatsbesuche bei Hitler in Berlin und München, Deutsches Reich, 1940 Der italienische Außenminister Graf Ciano Galleazzo trifft mit dem Zug in Berlin ein und wird von Reichaußenminister Joachim von Ribbentrop begrüßt. Beide werden durch die menschenumsäumten Straßen Berlins zur neuen Reichskanzlei gefahren, eine Sicherheitseskorte auf Krafträdern begleitet sie. Ciano trifft mit dem Auto im Ehrenhof der neuen Reichskanzlei ein. Er wird von vielen Leuten mit Handschlag begrüßt, geht die Treppe zur Reichskanzlei hoch und begibt sich zu einer Besprechung mit Hitler. Graf Ciano trifft mit dem Auto in München ein. An der dort stattfindenden Besprechung werden auch Hitler, der ungarische Ministerpräsident Graf Paul Teleki und Außenminister Graf Stefan Csáky beteiligt sein. Hitler trifft in München ein und wird jubelnd empfangen, u.a. von der Hitlerjugend (HJ) mit Hitlergruß. Am Hauptbahnhof begrüßt Ribbentrop die eintreffenden ungarischen Politiker Teleki und Csáky; Fahrt durch die von jubelnden Zuschauern umsäumten Straßen Münchens zum Führerbau am Königsplatz. Teleki, Csáky und Ribbentrop betreten das Gebäude und werden von Hitler begrüßt. 2. Französisch-britische Beziehungen, Italienisch-Libyen/Ägypten/Frankreich/Großbritannien, 1940 Britische Truppeneinheiten marschieren in Ägypten für die Vorbereitung des Angriffs gegen das italienische Libyen auf. Vorgehende britische Artillerietruppen und verrollende Panzereinheiten während eines Übungsschießens. Einmarsch französischer Truppeneinheiten in Nordafrika. Vorrücken der Infanterie für den Angriff auf Libyen. Der britische General John Gort zeichnet französische Soldaten mit Orden vor dem Waffenstillstand aus. Nach Abbruch der englisch-französischen diplomatischen Beziehungen verbot die französische Regierung das Tragen englischer Orden. Die Texttafel des Britannia-Denkmals in Boulougne, das 1914 anlässlich der Ankunft britischer Truppen errichtet wurde. Sprengung des Denkmals als Reaktion auf die „Operation Catapult“. Neueinberufene englische Rekruten beim Exerzieren. 3. Deutsche Kriegsbeute, Frankreich, 1940 Deutsche Beutelager im besetzten Frankreich; ein großes Warenlager. Berge von erbeuteten Helmen und Stapel von Rohlingen. Große Mengen von Geschützrohren und Granaten in einer Fabrikhalle werden gezeigt, ebenso erbeutete Maschinen, Zink, Quecksilber und Kupferlager. 4. Deutsche Truppen besorgen Nachschub in der Heimat, Deutsches Reich, 1940 Mit der Bahn treffen deutsche Truppenverbände wieder in Deutschland ein, um Waffen und Ausrüstung nachzuholen. Kinder spielen auf einem Panzer IV. Die Soldaten werden von der Bevölkerung empfangen. Zur Begrüßung der eintreffenden Truppen streuen Frauen und Kinder Blumen auf die Straßen einer Stadt. Eine Panzereinheit (Panzer III) fährt durch die Straßen einer Garnisonsstadt, vorbei an jubelnden Menschen. Unterlegt sind Soldatenlieder. 5. Kameradschaftsfest in einem Ruhequartier einer Einheit der Waffen-SS, Deutsches Reich, 1940 Bei einem Kameradschaftsfest in einem Ruhequartier einer Einheit der Waffen-SS- tritt Bruno Fritz auf und hält einen humorösen Vortrag zum Thema Eishockey; viel Beifall der Zuschauer. Lachende, junge Männer der Waffen-SS. 6. Seekrieg in Norwegen u ...

# %%
df[df["content"].notna()].apply(lambda row: save_chapters(row), axis=1)
# Out:
# episode                                                           511
# year                                                             1940
# filestem                                                     511_1940
# length                                                         2564.0
# fps                                                              25.0
# frames                                                        64123.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Verunglimpfung Nachtangriff Panzerspähwagen Re...
# content             1. Luftkrieg über Le Havre, Frankreich, 1940 N...
# Name: 0, dtype: object
# Skip
# episode                                                           512
# year                                                             1940
# filestem                                                     512_1940
# length                                                         2693.0
# fps                                                              24.0
# frames                                                        64652.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Verunglimpfung Seemine Flugzeugabschuss Granat...
# content             1. Deutsche Marineeinheiten, darunter Zerstöre...
# Name: 1, dtype: object
# Skip
# episode                                                           513
# year                                                             1940
# filestem                                                     513_1940
# length                                                         1630.0
# fps                                                              24.0
# frames                                                        39121.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Verunglimpfung Französischer Kriegsgefangener ...
# content             Vorfilm: Tran und Helle über die Ehe Tran und ...
# Name: 2, dtype: object
# Skip
# episode                                                           514
# year                                                             1940
# filestem                                                     514_1940
# length                                                         2143.0
# fps                                                              25.0
# frames                                                        53586.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Zweiter Weltkrieg Waffenstillstand / Frankreic...
# content             Vorfilm: Tran und Helle, Denunzieren Tran sitz...
# Name: 3, dtype: object
# Skip
# episode                                                           515
# year                                                             1940
# filestem                                                     515_1940
# length                                                         1658.0
# fps                                                              24.0
# frames                                                        39800.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Sanitäter Panzer Kriegsbeute Kradschützentrupp...
# content             Vorfilm: Verwundetenversorgung der deutschen W...
# Name: 4, dtype: object
# Skip
# episode                                                           516
# year                                                             1940
# filestem                                                     516_1940
# length                                                          529.0
# fps                                                              25.0
# frames                                                        13237.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Kradschützentruppe Seemine Kriegsschiff Artill...
# content             Vorfilm: Tran und Helle, Kettenbriefe Tran und...
# Name: 5, dtype: object
# Skip
# episode                                                           517
# year                                                             1940
# filestem                                                     517_1940
# length                                                         1920.0
# fps                                                              24.0
# frames                                                        46091.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Galopprennen Frachtschiff Torpedoboot Pionier ...
# content             Vorspann: Tran und Helle, Die Franzosen Tran u...
# Name: 6, dtype: object
# Skip
# episode                                                           518
# year                                                             1940
# filestem                                                     518_1940
# length                                                         1866.0
# fps                                                              24.0
# frames                                                        44801.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Seiltänzer Erntehelfer Plastik Französischer K...
# content             Vorfilm: Tran und Helle, Hamsterfahrt Tran und...
# Name: 7, dtype: object
# Skip
# episode                                                           519
# year                                                             1940
# filestem                                                     519_1940
# length                                                         1671.0
# fps                                                              24.0
# frames                                                        40117.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Eagle / Schiff, 1936- Kradschützentruppe Hinde...
# content             Vorfilm: Tarn und Helle, Meinungsfreiheit Tran...
# Name: 8, dtype: object
# Skip
# episode                                                           520
# year                                                             1940
# filestem                                                     520_1940
# length                                                         1926.0
# fps                                                              24.0
# frames                                                        46240.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Chemische Industrie Kriegsbeute Düngemittel Do...
# content             Vorfilm: Luftschutzunterricht zur Brandbombenb...
# Name: 9, dtype: object
# Skip
# episode                                                           521
# year                                                             1940
# filestem                                                     521_1940
# length                                                         1721.0
# fps                                                              24.0
# frames                                                        41321.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Bewirtschaftung Motorsport Ausbildung Do 217 E...
# content             Vorfilm: Tran und Helle, Kleiderkarte Tran und...
# Name: 10, dtype: object
# Skip
# episode                                                           522
# year                                                             1940
# filestem                                                     522_1940
# length                                                         1586.0
# fps                                                              24.0
# frames                                                        38081.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Erntehelfer Französischer Kriegsgefangener Sch...
# content             Vorfilm: Tran und Helle, Soziales Verhalten Tr...
# Name: 11, dtype: object
# Skip
# episode                                                           523
# year                                                             1940
# filestem                                                     523_1940
# length                                                         1523.0
# fps                                                              24.0
# frames                                                        36565.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Pharmazeutische Industrie Zweiter Weltkrieg Kr...
# content             1. Herbstmesse in Wien, Ostmark, 1940 Eröffnun...
# Name: 12, dtype: object
# Skip
# episode                                                           524
# year                                                             1940
# filestem                                                     524_1940
# length                                                         1975.0
# fps                                                              24.0
# frames                                                        47422.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Nachtangriff Torpedo Küstenartillerie Flugabwe...
# content             Vorfilm: Tran und Helle, Im Luftschutzkeller T...
# Name: 13, dtype: object
# Skip
# episode                                                           525
# year                                                             1940
# filestem                                                     525_1940
# length                                                          683.0
# fps                                                              25.0
# frames                                                        17080.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Fesselballon Erntehelfer Kriegswirtschaft Krad...
# content             1. Arbeitsdienst im Reichskommissariat Norwege...
# Name: 14, dtype: object
# Skip
# episode                                                           526
# year                                                             1940
# filestem                                                     526_1940
# length                                                         1839.0
# fps                                                              25.0
# frames                                                        45976.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Backwarenindustrie Kriegsbeute Gleisbau Wieder...
# content             1. Abzug englischer Truppen, China/Französisch...
# Name: 15, dtype: object
# Skip
# episode                                                           527
# year                                                             1940
# filestem                                                     527_1940
# length                                                         1740.0
# fps                                                              24.0
# frames                                                        41780.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Schlachtschiff Premio Cremona Ar 96 Kollaborat...
# content             1. Präsident Roosevelt bei Unterzeichnung der ...
# Name: 16, dtype: object
# Skip
# episode                                                           528
# year                                                             1940
# filestem                                                     528_1940
# length                                                         1685.0
# fps                                                              24.0
# frames                                                        40441.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Umsiedlung Granatwerfer Polenfeldzug / 1939 Fe...
# content             1. Bauarbeiten in Rom, Italien, 1940 Bauarbeit...
# Name: 17, dtype: object
# Skip
# episode                                                           529
# year                                                             1940
# filestem                                                     529_1940
# length                                                         1627.0
# fps                                                              25.0
# frames                                                        40679.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Französischer Kriegsgefangener Panzer Kinderla...
# content             1. England öffnet die Burma-Straße, Südostasie...
# Name: 18, dtype: object
# Skip
# episode                                                           530
# year                                                             1940
# filestem                                                     530_1940
# length                                                         1447.0
# fps                                                              25.0
# frames                                                        36198.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Zweiter Weltkrieg Militärmarsch Panzer Luftwaf...
# content             1. Reichsorganisationsleiter Ley besichtigt de...
# Name: 19, dtype: object
# Skip
# episode                                                           531
# year                                                             1940
# filestem                                                     531_1940
# length                                                         1376.0
# fps                                                              25.0
# frames                                                        34406.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Jagdgeschwader Kartoffelernte Segelflugzeug Pa...
# content             1. Gemüseernte, Deutsches Reich, 1940 Auflesen...
# Name: 20, dtype: object
# Skip
# episode                                                           532
# year                                                             1940
# filestem                                                     532_1940
# length                                                         1373.0
# fps                                                              25.0
# frames                                                        34332.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Zweiter Weltkrieg Straßenbau Hitlerputsch Kind...
# content             1. Architekturausstellung in Belgrad, Königrei...
# Name: 21, dtype: object
# Skip
# episode                                                           533
# year                                                             1940
# filestem                                                     533_1940
# length                                                         1664.0
# fps                                                              24.0
# frames                                                        39936.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Bodenturnen Fallschirmjäger Kinderlandverschic...
# content             1. Ausbau Hsinkings, Mandschuko, 1940 Stadtbil...
# Name: 22, dtype: object
# Skip
# episode                                                           534
# year                                                             1940
# filestem                                                     534_1940
# length                                                         1771.0
# fps                                                              25.0
# frames                                                        44276.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Katastrophenhilfe Französischer Kriegsgefangen...
# content             1. Bergungsarbeiten nach einem Erdbeben in Buk...
# Name: 23, dtype: object
# Skip
# episode                                                           535
# year                                                             1940
# filestem                                                     535_1940
# length                                                         1291.0
# fps                                                              24.0
# frames                                                        30989.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Zweiter Weltkrieg Straßenbau Militärmarsch Lav...
# content             1. Kaiserparade in Tokio, Japan, 1940 Kaiserpa...
# Name: 24, dtype: object
# Skip
# episode                                                           536
# year                                                             1940
# filestem                                                     536_1940
# length                                                         1670.0
# fps                                                              25.0
# frames                                                        41750.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Tirpitz / Schiff Blücher / Schiff, 1937-1940 D...
# content             1. Japanischer Luftangriff auf Kunming, China,...
# Name: 25, dtype: object
# Skip
# episode                                                           537
# year                                                             1940
# filestem                                                     537_1940
# length                                                          965.0
# fps                                                              24.0
# frames                                                        23168.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Arbeiter Feldhaubitze Rüstung Weihnachten Para...
# content             1. Genesungsheim für deutsche Soldaten in der ...
# Name: 26, dtype: object
# Skip
# episode                                                           538
# year                                                             1940
# filestem                                                     538_1940
# length                                                         1547.0
# fps                                                              25.0
# frames                                                        38692.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Kinderlandverschickung Waffenproduktion Nahver...
# content             1. Japanischer Bombenangriff auf die Burmastra...
# Name: 27, dtype: object
# Skip
# episode                                                           539
# year                                                             1940
# filestem                                                     539_1940
# length                                                         1482.0
# fps                                                              25.0
# frames                                                        37066.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Zweiter Weltkrieg Kinderlandverschickung Dreim...
# content             Vorfilm über das Verhalten im Straßenverkehr b...
# Name: 28, dtype: object
#    chapter                                            content
# 0        1  1. Deutsche Buchausstellung im „Haus der Deuts...
# 1        2  2. Frauenhochschule in Orvieto, Italien, 1940 ...
# 2        3  3. Großkundgebung in Tokio, Japanisches Kaiser...
# 3        4  4. Pétain besucht Lyon, Frankreich, 1940 Der F...
# 4        5  5. Hitler empfängt den sowjetischen Botschafte...
# 5        6  6. RAD beim Bau eines Flugplatzes im besetzten...
# 6        7  7. Uferregulierungsarbeiten an der Weichsel, G...
# 7        8  8. Berliner Jungen in Zakopane, Generalgouvern...
# 8        9  9. Weihnachten 1940: Weihnachtsfeier für Kinde...
# 9       10  10. Weihnachten 1940: Ley beschert Kinder gefa...
# 10      11  11. Weihnachten 1940: Feier für Soldatenkinder...
# 11      12  12. Weihnachten 1940: Goebbels bei einer Flakb...
# 12      13  13. Weihnachten 1940: Eintreffen der Weihnacht...
# 13      14  14. Weihnachten 1940: Bescherung bei den Nachr...
# 14      15  15. Weihnachten 1940: Hitler und von Brauchits...
# 15      16  16. Weihnachten 1940: Heß besucht ein Kampfges...
# 16      17  17. Weihnachten 1940: Hitler besucht Flieger a...
# episode                                                           540
# year                                                             1940
# filestem                                                     540_1940
# length                                                          829.0
# fps                                                              25.0
# frames                                                        20745.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Schlachtschiff Zweiter Weltkrieg Minenabwehr N...
# content             1. Zusammenbruch der Tacoma-Narrows-Brücke, Wa...
# Name: 29, dtype: object
# Skip
# episode                                                           541
# year                                                             1940
# filestem                                                     541_1940
# length                                                         1294.0
# fps                                                              24.0
# frames                                                        31059.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Zweiter Weltkrieg Kriegsbeute Handelsschiff To...
# content             1. Gedenkfeier für gefallene japanische Soldat...
# Name: 30, dtype: object
# Skip
# episode                                                           542
# year                                                             1941
# filestem                                                     542_1941
# length                                                         1223.0
# fps                                                              24.0
# frames                                                        29366.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Zweiter Weltkrieg Samurai Kradschützentruppe R...
# content             1. Abschluss der 2600-Jahr Feier des Japanisch...
# Name: 31, dtype: object
# Skip
# episode                                                           543
# year                                                             1941
# filestem                                                     543_1941
# length                                                         1377.0
# fps                                                              24.0
# frames                                                        33064.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Stahlhelm SdKfz 251 Flugzeugstaffel SdKfz 250 ...
# content             1. 85. Geburtstag des Komponisten Sinding, Rei...
# Name: 32, dtype: object
# Skip
# episode                                                           544
# year                                                             1941
# filestem                                                     544_1941
# length                                                         1504.0
# fps                                                              24.0
# frames                                                        36110.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Zweiter Weltkrieg Freizeitgestaltung Schneeräu...
# content             1. Staatsakt für den am 29.01.1941 verstorbene...
# Name: 33, dtype: object
# Skip
# episode                                                           545
# year                                                             1941
# filestem                                                     545_1941
# length                                                         1495.0
# fps                                                              25.0
# frames                                                        37392.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Deutscher Schäferhund Wintersport Panzerspähwa...
# content             1. Beisetzung des ungarischen Außenministers G...
# Name: 34, dtype: object
# Skip
# episode                                                           546
# year                                                             1941
# filestem                                                     546_1941
# length                                                         1395.0
# fps                                                              24.0
# frames                                                        33499.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Sanitäter Plastik Wasserkraftgenerator Bildhau...
# content             1. Jugoslawischer Ministerpräsident Cvetković ...
# Name: 35, dtype: object
# Skip
# episode                                                           547
# year                                                             1941
# filestem                                                     547_1941
# length                                                         1727.0
# fps                                                              25.0
# frames                                                        43195.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Fallschirmjäger Chemische Industrie Umsiedlung...
# content             1. Staatsakt für SA-Obergruppenführer Kriebel,...
# Name: 36, dtype: object
#    chapter                                            content
# 0        1  1. Staatsakt für SA-Obergruppenführer Kriebel,...
# 1        2  2. Reichsmarschall Göring bei einer Luftwaffen...
# 2        3  3. Reichsmarschall Göring bei Hitler auf dem B...
# 3        4  4. Treffen von Mussolini, Franco und Außenmini...
# 4        5  5. Ankunft des japanischen Botschafters Ōshima...
# 5        6  6. Japanische Militärkommission bei Formatione...
# 6        7  7. Umsiedlung litauischer „Volksdeutscher“ nac...
# 7        8  8. Inbetriebnahme des Stickstoffwerkes in Tarn...
# 8        9  9. Vereidigung der SA-Standarte „52“, Prag, Re...
# 9       10  10. Kriegstagung der Reichsfilmkammer, Berlin,...
# 10      11  11. Filmvolkstag, Berlin, Deutsches Reich, 194...
# 11      12  12. Polizeisportfest in der Deutschlandhalle, ...
# 12      13  13. Boxer Schmeling bei einer Fallschirmjägere...
# 13      14  14. Regiment SS-Leibstandarte „Adolf Hitler“, ...
# 14      15  15. Deutsche Flieger-Offiziere, Sizilien, Ital...
# 15      16  16. Deutscher Hilfskreuzer „Widder“ im Süd-Atl...
# episode                                                           548
# year                                                             1941
# filestem                                                     548_1941
# length                                                         1746.0
# fps                                                              24.0
# frames                                                        41927.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Skilauf Hundeausbildung Panzer Bergführer / Pe...
# content             1. Parteigründungsfeier der NSDAP, München, De...
# Name: 37, dtype: object
# Skip
# episode                                                           549
# year                                                             1941
# filestem                                                     549_1941
# length                                                         1681.0
# fps                                                              25.0
# frames                                                        42032.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Seemine Kriegsschiff Flugabwehr Kriegsgefangen...
# content             1. Minenräumung auf dem Jangtsekiang, China, 1...
# Name: 38, dtype: object
# Skip
# episode                                                           551
# year                                                             1941
# filestem                                                     551_1941
# length                                                         1418.0
# fps                                                              25.0
# frames                                                        35469.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Hürdenlauf Gleisbau Tunnelbau Karikatur Kriegs...
# content             1. Japanische Landungstruppen bei der Überfahr...
# Name: 40, dtype: object
# Skip
# episode                                                           552
# year                                                             1941
# filestem                                                     552_1941
# length                                                         1680.0
# fps                                                              24.0
# frames                                                        40342.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Schlachtschiff Panzerspähwagen Kradschützentru...
# content             1. Aufnahme von Jugendgruppen in die HJ und in...
# Name: 41, dtype: object
# Skip
# episode                                                           553
# year                                                             1941
# filestem                                                     553_1941
# length                                                         1927.0
# fps                                                              25.0
# frames                                                        48198.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Torpedo Umsiedlung Rüstung Erdölbohrung Artill...
# content             1. Beisetzung des Sanitätsinspektors Generalob...
# Name: 42, dtype: object
# Skip
# episode                                                           554
# year                                                             1941
# filestem                                                     554_1941
# length                                                         2035.0
# fps                                                              24.0
# frames                                                        48853.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Thompson / Maschinenpistole Panzerspähwagen Se...
# content             1. Nachschub für das deutsche Afrikakorps wird...
# Name: 43, dtype: object
# Skip
# episode                                                           555
# year                                                             1941
# filestem                                                     555_1941
# length                                                         2049.0
# fps                                                              24.0
# frames                                                        49191.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Fallschirmjäger Serbischer Kriegsgefangener Kr...
# content             1. 52. Geburtstag von Adolf Hitler am 20.04.19...
# Name: 44, dtype: object
# Skip
# episode                                                           556
# year                                                             1941
# filestem                                                     556_1941
# length                                                         1779.0
# fps                                                              24.0
# frames                                                        42702.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Panzer Panzerspähwagen Serbischer Kriegsgefang...
# content             1. Der deutsche Hilfskreuzer „Kormoran“ bei de...
# Name: 45, dtype: object
# Skip
# episode                                                           557
# year                                                             1941
# filestem                                                     557_1941
# length                                                          693.0
# fps                                                              25.0
# frames                                                        17338.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Fallschirmjäger Kriegsbeute Kradschützentruppe...
# content             1. Auszeichnung von NS-Betrieben am ersten Mai...
# Name: 46, dtype: object
# Skip
# episode                                                           558
# year                                                             1941
# filestem                                                     558_1941
# length                                                         1277.0
# fps                                                              25.0
# frames                                                        31934.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Panzerspähwagen Kradschützentruppe Panzerkampf...
# content             1. Bau einer Behelfsbrücke über die Donau bei ...
# Name: 47, dtype: object
# Skip
# episode                                                           559
# year                                                             1941
# filestem                                                     559_1941
# length                                                         1285.0
# fps                                                              24.0
# frames                                                        30858.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Serbischer Kriegsgefangener Torpedo Kradschütz...
# content             1. Produktion in einem japanischen Rüstungsbet...
# Name: 48, dtype: object
# Skip
# episode                                                           560
# year                                                             1941
# filestem                                                     560_1941
# length                                                         1651.0
# fps                                                              24.0
# frames                                                        39635.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Fußball Schlachtschiff Fallschirmjäger Reitsch...
# content             1. Japanischer Luftangriff im Süden von China,...
# Name: 49, dtype: object
# Skip
# episode                                                           561
# year                                                             1941
# filestem                                                     561_1941
# length                                                         1717.0
# fps                                                              24.0
# frames                                                        41219.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Fallschirmjäger Panzer Feldhaubitze Kriegszers...
# content             1. Besichtigung einer PK zum 60.Geburtstag von...
# Name: 50, dtype: object
# Skip
# episode                                                           562
# year                                                             1941
# filestem                                                     562_1941
# length                                                         1640.0
# fps                                                              25.0
# frames                                                        41001.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Gebirgstruppe Fallschirmjäger Panzerspähwagen ...
# content             1. Treffen zwischen Hitler und Mussolini am Br...
# Name: 51, dtype: object
# Skip
# episode                                                           563
# year                                                             1941
# filestem                                                     563_1941
# length                                                         1478.0
# fps                                                              25.0
# frames                                                        36952.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Panzerspähwagen Kinderlandverschickung Landung...
# content             1. Parade der thailändischen Armee anlässlich ...
# Name: 52, dtype: object
# Skip
# episode                                                           564
# year                                                             1941
# filestem                                                     564_1941
# length                                                         1646.0
# fps                                                              24.0
# frames                                                        39514.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Verunglimpfung Fußball Russlandfeldzug / 1941-...
# content             Vorspann: Die Sache mit der Uhr Kabarett-Werbu...
# Name: 53, dtype: object
# Skip
# episode                                                           565
# year                                                             1941
# filestem                                                     565_1941
# length                                                         2384.0
# fps                                                              24.0
# frames                                                        57238.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Russlandfeldzug / 1941-1945 Panzerspähwagen Kr...
# content             1. Brennende Häuser im sowjetisch-finnischen W...
# Name: 54, dtype: object
# Skip
# episode                                                           566
# year                                                             1941
# filestem                                                     566_1941
# length                                                         1978.0
# fps                                                              25.0
# frames                                                        49460.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Verunglimpfung Russlandfeldzug / 1941-1945 Pan...
# content             1. Deutsche Flugstaffel Aufklärungseinsatz an ...
# Name: 55, dtype: object
# Skip
# episode                                                           567
# year                                                             1941
# filestem                                                     567_1941
# length                                                         2360.0
# fps                                                              24.0
# frames                                                        56650.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Verunglimpfung Russlandfeldzug / 1941-1945 Pan...
# content             1. Bildung von Freiwilligenverbänden und Demon...
# Name: 56, dtype: object
# Skip
# episode                                                           568
# year                                                             1941
# filestem                                                     568_1941
# length                                                         2286.0
# fps                                                              25.0
# frames                                                        57160.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Verunglimpfung Russlandfeldzug / 1941-1945 Pan...
# content             Vorspann: Aufruf zur Reichsspinnstoffsammlung ...
# Name: 57, dtype: object
# Skip
# episode                                                           569
# year                                                             1941
# filestem                                                     569_1941
# length                                                         2017.0
# fps                                                              24.0
# frames                                                        48413.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Verunglimpfung Russlandfeldzug / 1941-1945 Pan...
# content             1. Göring empfängt in seinem Hauptquartier an ...
# Name: 58, dtype: object
# Skip
# episode                                                           570
# year                                                             1941
# filestem                                                     570_1941
# length                                                         1232.0
# fps                                                              25.0
# frames                                                        30801.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Verunglimpfung Sanitäter Deportation Russlandf...
# content             1. Hitler besucht deutsche Truppen der Heeresg...
# Name: 59, dtype: object
# Skip
# episode                                                           571
# year                                                             1941
# filestem                                                     571_1941
# length                                                          648.0
# fps                                                              25.0
# frames                                                        16218.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Verunglimpfung Sanitäter Russlandfeldzug / 194...
# content             1. Großkundgebung der französischen Freiwillig...
# Name: 60, dtype: object
# Skip
# episode                                                           572
# year                                                             1941
# filestem                                                     572_1941
# length                                                         1955.0
# fps                                                              24.0
# frames                                                        46920.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Verunglimpfung Sanitäter Russlandfeldzug / 194...
# content             1. Verabschiedung wallonischer Freiwilliger, B...
# Name: 61, dtype: object
# Skip
# episode                                                           573
# year                                                             1941
# filestem                                                     573_1941
# length                                                          671.0
# fps                                                              25.0
# frames                                                        16785.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Verunglimpfung Russlandfeldzug / 1941-1945 Flu...
# content             1. Fliegerangriff auf Murmansk, Russische Sozi...
# Name: 62, dtype: object
# Skip
# episode                                                           574
# year                                                             1941
# filestem                                                     574_1941
# length                                                         1920.0
# fps                                                              25.0
# frames                                                        48001.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Verunglimpfung Sanitäter Schiffbau Russlandfel...
# ...
# keywords            Fesselballon Sarg Russlandfeldzug / 1941-1945 ...
# content             1. Ehrung, Berlin, Deutsches Reich, 1944. Helm...
# Name: 225, dtype: object
# Skip
# episode                                                           738
# year                                                             1944
# filestem                                                     738_1944
# length                                                          725.0
# fps                                                              25.0
# frames                                                        18148.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Generalfeldmarschall Russlandfeldzug / 1941-19...
# content             1. Ehrung, Ulm, Deutsches Reich, 14.10.1944. (...
# Name: 226, dtype: object
# Skip
# episode                                                           739
# year                                                             1944
# filestem                                                     739_1944
# length                                                          812.0
# fps                                                              24.0
# frames                                                        19490.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Kaugummi Russlandfeldzug / 1941-1945 Panzer Fl...
# content             1. Ernte, Deutsches Reich, 1944. Frauen bei de...
# Name: 227, dtype: object
# Skip
# episode                                                           740
# year                                                             1944
# filestem                                                     740_1944
# length                                                          800.0
# fps                                                              24.0
# frames                                                        19206.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Russlandfeldzug / 1941-1945 Panzer Granatwerfe...
# content             1. Kartoffel, Dresden, Deutsches Reich, 1944. ...
# Name: 228, dtype: object
# Skip
# episode                                                           741
# year                                                             1944
# filestem                                                     741_1944
# length                                                          768.0
# fps                                                              24.0
# frames                                                        18455.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Generalfeldmarschall Russlandfeldzug / 1941-19...
# content             1. Ehrung, München, Deutsches Reich, 9.11.1944...
# Name: 229, dtype: object
# Skip
# episode                                                           742
# year                                                             1944
# filestem                                                     742_1944
# length                                                          766.0
# fps                                                              24.0
# frames                                                        18399.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Belagerung Panzer Russlandfeldzug / 1941-1945 ...
# content             1. Ehrung, Wien, annektiertes Österreich, 1944...
# Name: 230, dtype: object
# Skip
# episode                                                           743
# year                                                             1944
# filestem                                                     743_1944
# length                                                          770.0
# fps                                                              24.0
# frames                                                        18496.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Belagerung Eiszapfen Russlandfeldzug / 1941-19...
# content             1. Zauberkunst, Deutsches Reich, 1944. (Sprech...
# Name: 231, dtype: object
# Skip
# episode                                                           744
# year                                                             1944
# filestem                                                     744_1944
# length                                                          667.0
# fps                                                              24.0
# frames                                                        16028.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Grenze Russlandfeldzug / 1941-1945 Panzer Lehr...
# content             1. Ausbildung, Reichsbahn, Deutsches Reich, 19...
# Name: 232, dtype: object
# Skip
# episode                                                           745
# year                                                             1944
# filestem                                                     745_1944
# length                                                          784.0
# fps                                                              25.0
# frames                                                        19621.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Generalfeldmarschall Russlandfeldzug / 1941-19...
# content             1. Ehrung, Deutsches Reich, 1944. (Sprecher:) ...
# Name: 233, dtype: object
# Skip
# episode                                                           746
# year                                                             1944
# filestem                                                     746_1944
# length                                                          892.0
# fps                                                              25.0
# frames                                                        22308.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Elektronenstrahlröhre Fallschirmjäger Frau Pan...
# content             1. Medizinische Wissenschaft, Deutsches Reich,...
# Name: 234, dtype: object
# Skip
# episode                                                           747
# year                                                             1945
# filestem                                                     747_1945
# length                                                          755.0
# fps                                                              24.0
# frames                                                        18134.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Panzer Artillerie Wintersonnenwende Rückzug Ge...
# content             1. Sonnenwendfeier der Hitlerjugend, 22.12.194...
# Name: 235, dtype: object
# Skip
# episode                                                           748
# year                                                             1945
# filestem                                                     748_1945
# length                                                          817.0
# fps                                                              24.0
# frames                                                        19610.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Zweiter Weltkrieg Panzer Russlandfeldzug / 194...
# content             Vorfilm: Werbung für die Spinnstoff-Sammlung, ...
# Name: 236, dtype: object
# Skip
# episode                                                           749
# year                                                             1945
# filestem                                                     749_1945
# length                                                          653.0
# fps                                                              24.0
# frames                                                        15688.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Geleitzug Nebelwerfer Flugabwehrartillerie V 2...
# content             1. Ehrung, Deutsches Reich, 1945.  Zum 100. Ge...
# Name: 237, dtype: object
#   chapter                                            content
# 0       1  1. Ehrung, Deutsches Reich, 1945. Zum 100. Geb...
# 1       2  2. Reichsbahn, Deutsches Reich, 1945. Neue Beh...
# 2       3  3. Volksopfer, Deutsches Reich, 1945. Hitlerju...
# 3       4  4. Seekrieg, Europa, 1945. Deutscher Geleitzug...
# 4       5  5. Rückzug, Ungarn, 1945. Kartentrick: Ungarn,...
# 5       6  6. Amphibische Kriegsführung, Niederlande, 194...
# 6       7  7. Panzerabwehr, Europa, 1945. Großaufnahme vo...
# 7       8  8. Saargebiet, Deutsches Reich, 1945. Deutsche...
# 8       9  9. Vergeltungswaffe 2, Europa, 1945. Küstenlan...
# episode                                                           750
# year                                                             1945
# filestem                                                     750_1945
# length                                                          718.0
# fps                                                              24.0
# frames                                                        17252.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Skilauf Panzer Granatwerfer Uniform Energie T ...
# content             Vorfilm: Aufforderung zum Strom sparen zugunst...
# Name: 238, dtype: object
#    chapter                                            content
# 0  Vorfilm  Aufforderung zum Strom sparen zugunsten der Rü...
# 1        1  1. Kriegsbeschädigung, Deutsches Reich, 1945. ...
# 2        2  2. Volkssturm, Deutsches Reich, 1945. Volksstu...
# 3        3  3. Sprengboote, Niederlande (?), 1945. Mitglie...
# 4        4  4. Bunkeranlage, Deutsches Reich, 1945. Konden...
# 5        5  5. K.“ Eine Frau nimmt unter Tage mit einer Gr...
# 6        6  6. Rückzug, Deutsches Reich, Niederlande (?), ...
# 7        7  7. Rückzug, Deutsches Reich, Polen, 1945. Kart...
# 8        8  8. Rückzug, Deutsches Reich, Polen, 1945. Panz...
# episode                                                           751
# year                                                             1945
# filestem                                                     751_1945
# length                                                          659.0
# fps                                                              24.0
# frames                                                        15837.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Fuhrwerk Schneetreiben Panzer Lastkraftwagen A...
# content             1. Kriegsgefangenschaft, Deutsches Reich, 1945...
# Name: 239, dtype: object
#   chapter                                            content
# 0       1  1. Kriegsgefangenschaft, Deutsches Reich, 1945...
# 1       2  2. Rückzug, Deutsches Reich, Frankreich, Niede...
# 2       3  3. Flucht, Deutsches Reich, 1945. Kartentrick:...
# 3       4  4. Rückzug, Osteuropa, 1945. Männer des Volkss...
# 4       5  5. Schlacht um Ostpreußen, Deutsches Reich, 19...
# 5       6  6. Logistik, Osteuropa, 1945. Deutsche Transpo...
# 6       7  7. Kurlandkessel, Sowjetunion, 1945. Eine Küst...
# 7       8  8. Schlacht um Budapest, Ungarn, 1945. Kartent...
# 8       9  9. Rückzug, Ungarn, 1945. Sturmgeschütze auf v...
# 9      10  10. Rückzug, Ungarn (?), 1945. Eine Kolonne de...
# episode                                                           752
# year                                                             1945
# filestem                                                     752_1945
# length                                                          648.0
# fps                                                              24.0
# frames                                                        15565.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Fallschirmjäger Nachschub Panzer Lastkraftwage...
# content             1. Textilverarbeitung, Deutsches Reich, 1945. ...
# Name: 240, dtype: object
# Skip
# episode                                                           753
# year                                                             1945
# filestem                                                     753_1945
# length                                                          672.0
# fps                                                              24.0
# frames                                                        16145.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Panzer Granatwerfer Flugabwehrartillerie T 34 ...
# content             1. Zum 80. Geburtstag des schwedischen Forsche...
# Name: 241, dtype: object
#   chapter                                            content
# 0       1  1. Zum 80. Geburtstag des schwedischen Forsche...
# 1       2  2. Reichsarbeitsführer Konstantin Hierl besuch...
# 2       3  3. Die Wochenschau befragt den verwundeten Jag...
# 3       4  4. Volkssturm und Zivilisten bei Schanzarbeite...
# 4       5  5. Deutsches U-Boot mit Schnorchel im Einsatz,...
# 5       6  6. Deutsche Infanterie im Einsatz an der Westf...
# 6       7  7. Deutsche Soldaten, die in Budapest eingesch...
# 7       8  8. Rückzug, „Im schlesischen Kampfraum“, Deuts...
# 8       9  9. Rückzug, Oderstellung, Deutsches Reich, 194...
# episode                                                           754
# year                                                             1945
# filestem                                                     754_1945
# length                                                          801.0
# fps                                                              25.0
# frames                                                        20029.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Fuhrwerk Hund Russlandfeldzug / 1941-1945 Panz...
# content             1. Streik, Chicago, USA, 1937. (Sprecher:) „St...
# Name: 242, dtype: object
# Skip
# episode                                                           755
# year                                                             1945
# filestem                                                     755_1945
# length                                                          664.0
# fps                                                              24.0
# frames                                                        15949.0
# url_bundesarchiv    https://digitaler-lesesaal.bundesarchiv.de/vid...
# url_m3u8            https://digitaler-lesesaal.bundesarchiv.de/lix...
# keywords            Frau Vergewaltigung Russlandfeldzug / 1941-194...
# content             1. Entschärfung, Berlin, Deutsches Reich, 1945...
# Name: 243, dtype: object
# Skip
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
#        ...
# 239    None
# 240    None
# 241    None
# 242    None
# 243    None
# Length: 243, dtype: object
